# %% [markdown]
# # Cherry Blossoms!
#
# If we travel back in time, [cherry blossoms](https://en.wikipedia.org/wiki/Cherry_blossom) were once in full bloom! We don't live in Japan or DC, but we do have the [Brooklyn Botanic Garden's annual festival](https://www.bbg.org/visit/event/sakura_matsuri_2020) (whenever COVID isn't ruining things, at least).
#
# We'll have to make up for it with data-driven cherry blossoms instead. Once upon a time [Data is Plural](https://tinyletter.com/data-is-plural) linked to [a dataset](http://atmenv.envi.osakafu-u.ac.jp/aono/kyophenotemp4/) about when the cherry trees blossom each year. It's completely out of date, but it's quirky in a real nice way so we're sticking with it.
#
# ## 0. Do all of your importing/setup stuff

# %%
# !ls
# Out:
# Cherry Blossoms.ipynb KyotoFullFlower7.xls

# %%
# %time
import pandas as pd
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 8.82 µs

# %% [markdown]
# ## 1. Read in the file using pandas, and look at the first five rows

# %%
import pandas as pd
df = pd.read_excel("KyotoFullFlower7.xls")
df.head(5)
# Out:
#   Full-flowering dates of Japanese cherry (Prunus jamasakura) at Kyoto, Japan. (Latest version, Jun. 12, 2012)  \
# 0  This phenological data was acquired by followi...
# 1                                                NaN
# 2                                     Column A; A.D.
# 3       Column B; Full-flowering date (day of year).
# 4  Column C; Full-flowering date (calender date, ...
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN

# %% [markdown]
# ## 2. Read in the file using pandas CORRECTLY, and look at the first five rows
#
# Hrm, how do your column names look? Read the file in again but this time add a parameter to make sure your columns look right.
#
#
# * **TIP:** Look at the documentation for `read_excel` and `read_csv` to see if there's anything that allows you to skip rows*
# * **TIP:** The first year should be 801 AD, and it should not have any dates or anything.

# %%
df = pd.read_excel("KyotoFullFlower7.xls", skiprows = 25)
df.head(5)
# Out:
#     AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0  801                        NaN                  NaN          NaN
# 1  802                        NaN                  NaN          NaN
# 2  803                        NaN                  NaN          NaN
# 3  804                        NaN                  NaN          NaN
# 4  805                        NaN                  NaN          NaN
#
#    Data type code Reference Name
# 0             NaN              -
# 1             NaN              -
# 2             NaN              -
# 3             NaN              -
# 4             NaN              -

# %% [markdown]
# ## 3. Look at a random selection of 10 rows of data

# %%
df.head(10)
# Out:
#     AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0  801                        NaN                  NaN          NaN
# 1  802                        NaN                  NaN          NaN
# 2  803                        NaN                  NaN          NaN
# 3  804                        NaN                  NaN          NaN
# 4  805                        NaN                  NaN          NaN
# 5  806                        NaN                  NaN          NaN
# 6  807                        NaN                  NaN          NaN
# 7  808                        NaN                  NaN          NaN
# 8  809                        NaN                  NaN          NaN
# 9  810                        NaN                  NaN          NaN
#
#    Data type code Reference Name
# 0             NaN              -
# 1             NaN              -
# 2             NaN              -
# 3             NaN              -
# 4             NaN              -
# 5             NaN              -
# 6             NaN              -
# 7             NaN              -
# 8             NaN              -
# 9             NaN              -

# %% [markdown]
# ## 4. Add some more NaN values

# %% [markdown]
# It looks like you should probably have some NaN/missing values earlier on in the dataset under "Reference name." Read in the file *one more time*, this time making sure all of those missing reference names actually show up as `NaN` instead of `-`.

# %%
#df = pd.read_excel("KyotoFullFlower7.xls", skiprows = 25, na_values=['-'])
df = pd.read_excel("KyotoFullFlower7.xls", skiprows = 25, na_values=['-'])
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(" ", "_")
df
# Out:
#         ad  full-flowering_date_(doy)  full-flowering_date  source_code  \
# 0      801                        NaN                  NaN          NaN
# 1      802                        NaN                  NaN          NaN
# 2      803                        NaN                  NaN          NaN
# 3      804                        NaN                  NaN          NaN
# 4      805                        NaN                  NaN          NaN
# ...    ...                        ...                  ...          ...
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       data_type_code          reference_name
# 0                NaN                     NaN
# 1                NaN                     NaN
# 2                NaN                     NaN
# 3                NaN                     NaN
# 4                NaN                     NaN
# ...              ...                     ...
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)
#
# [1215 rows x 6 columns]

# %% [markdown]
# ## 4. What source is the most common as a reference?

# %%
df.reference_name.value_counts().head(5)
# Out:
# NEWS-PAPER(ARASHIYAMA)        94
# SUGIURAKE-NIKKI               38
# MYOHOIN-HINAMIKI              32
# OYUDONONO-UENO-NIKKI          26
# OYUDONONO-UENO-NIKKI [EDA]    21
# Name: reference_name, dtype: int64

# %% [markdown]
# ## 6. Filter the list to only include columns where the `Full-flowering date (DOY)` is not missing
#
# If you'd like to do it in two steps (which might be easier to think through), first figure out how to test whether a column is empty/missing/null/NaN, get the list of `True`/`False` values, and then later feed it to your `df`.

# %%
df = pd.read_excel("KyotoFullFlower7.xls", skiprows = 25, na_values=['-'])
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace("-", "_")
df.columns = df.columns.str.replace(" ", "_")
df.columns = df.columns.str.replace("(", "")
df.columns = df.columns.str.replace(")", "")
df.head(5)

#new_df = pd.isnull(df["Full-flowering date (DOY)"])
#new_df


#new_df = pd.isnull(df["full_flowering_date_doy"])
#df(new_df)
# Out:
# /var/folders/n1/4svfr7bj3599pf0j1ss9dr5h0000gn/T/ipykernel_18615/662715995.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace("(", "")
# /var/folders/n1/4svfr7bj3599pf0j1ss9dr5h0000gn/T/ipykernel_18615/662715995.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace(")", "")
#     ad  full_flowering_date_doy  full_flowering_date  source_code  \
# 0  801                      NaN                  NaN          NaN
# 1  802                      NaN                  NaN          NaN
# 2  803                      NaN                  NaN          NaN
# 3  804                      NaN                  NaN          NaN
# 4  805                      NaN                  NaN          NaN
#
#    data_type_code reference_name
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN

# %%
new_df = df.full_flowering_date_doy.value_counts().head(10)
new_df
#new_df.full_flowering_date_doy.value_counts()value_counts().sort_index()
# Out:
# 104.0    56
# 105.0    53
# 106.0    49
# 102.0    48
# 103.0    47
# 108.0    46
# 107.0    41
# 109.0    41
# 101.0    38
# 98.0     37
# Name: full_flowering_date_doy, dtype: int64

# %%
new_df = df[df.full_flowering_date_doy.isnull()]
new_df =df.dropna()
new_df =df.dropna(axis=0)
new_df
#df[["Full-flowering date (DOY)"]].isnull()
# Out:
#         ad  full_flowering_date_doy  full_flowering_date  source_code  \
# 11     812                     92.0                401.0          1.0
# 14     815                    105.0                415.0          1.0
# 30     831                     96.0                406.0          1.0
# 50     851                    108.0                418.0          1.0
# 52     853                    104.0                414.0          1.0
# ...    ...                      ...                  ...          ...
# 1210  2011                     99.0                409.0          8.0
# 1211  2012                    101.0                410.0          8.0
# 1212  2013                     93.0                403.0          8.0
# 1213  2014                     94.0                404.0          8.0
# 1214  2015                     93.0                403.0          8.0
#
#       data_type_code          reference_name
# 11               2.0              NIHON-KOKI
# 14               2.0              NIHON-KOKI
# 30               2.0              NIHON-KOKI
# 50               2.0  MONTOKUTENNO-JITSUROKU
# 52               2.0  MONTOKUTENNO-JITSUROKU
# ...              ...                     ...
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)
#
# [825 rows x 6 columns]

# %%
#df = pd.read_excel("KyotoFullFlower7.xls", skiprows = 25, na_values=['-'])

# %% [markdown]
# ## 7. Make a histogram of the full-flowering date

# %%
df.full_flowering_date_doy.hist(bins=10)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## 8. Make another histogram of the full-flowering date, but with 39 bins instead of 10

# %%
df.full_flowering_date_doy.hist(bins=39)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## 9a. What's the average number of days it takes for the flowers to blossom?

# %%
df.full_flowering_date_doy.describe()
# Out:
# count    827.000000
# mean     104.540508
# std        6.407036
# min       86.000000
# 25%      100.000000
# 50%      105.000000
# 75%      109.000000
# max      124.000000
# Name: full_flowering_date_doy, dtype: float64

# %% [markdown]
# ## 9b. And how many records do we have?
#
# You can actually answer this one and the last one with a single line of code.

# %%
#the total records is 827

# %% [markdown]
# ## 10. How many days into the year did cherry flowers normally blossom before 1900?

# %%
new_df[df['ad'] < 1900]


#df[df['full_flowering_date'] > 1900]
#[df[]1900]
# Out:
# /var/folders/n1/4svfr7bj3599pf0j1ss9dr5h0000gn/T/ipykernel_18615/1523864761.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new_df[df['ad'] < 1900]
#         ad  full_flowering_date_doy  full_flowering_date  source_code  \
# 11     812                     92.0                401.0          1.0
# 14     815                    105.0                415.0          1.0
# 30     831                     96.0                406.0          1.0
# 50     851                    108.0                418.0          1.0
# 52     853                    104.0                414.0          1.0
# ...    ...                      ...                  ...          ...
# 1093  1894                     98.0                408.0          4.0
# 1095  1896                    106.0                415.0          4.0
# 1096  1897                    106.0                416.0          4.0
# 1097  1898                    108.0                418.0          4.0
# 1098  1899                     99.0                409.0          4.0
#
#       data_type_code          reference_name
# 11               2.0              NIHON-KOKI
# 14               2.0              NIHON-KOKI
# 30               2.0              NIHON-KOKI
# 50               2.0  MONTOKUTENNO-JITSUROKU
# 52               2.0  MONTOKUTENNO-JITSUROKU
# ...              ...                     ...
# 1093             0.0  NEWS-PAPER(ARASHIYAMA)
# 1095             0.0  NEWS-PAPER(ARASHIYAMA)
# 1096             0.0  NEWS-PAPER(ARASHIYAMA)
# 1097             0.0  NEWS-PAPER(ARASHIYAMA)
# 1098             0.0  NEWS-PAPER(ARASHIYAMA)
#
# [712 rows x 6 columns]

# %% [markdown]
# ## 11. How about after 1900?

# %%
new_df = new_df[df['ad'] > 1900]
new_df =df.dropna()
new_df =df.dropna(axis=0)
new_df
#dif_df
# Out:
# /var/folders/n1/4svfr7bj3599pf0j1ss9dr5h0000gn/T/ipykernel_18615/3457472178.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new_df = new_df[df['ad'] > 1900]
#         ad  full_flowering_date_doy  full_flowering_date  source_code  \
# 11     812                     92.0                401.0          1.0
# 14     815                    105.0                415.0          1.0
# 30     831                     96.0                406.0          1.0
# 50     851                    108.0                418.0          1.0
# 52     853                    104.0                414.0          1.0
# ...    ...                      ...                  ...          ...
# 1210  2011                     99.0                409.0          8.0
# 1211  2012                    101.0                410.0          8.0
# 1212  2013                     93.0                403.0          8.0
# 1213  2014                     94.0                404.0          8.0
# 1214  2015                     93.0                403.0          8.0
#
#       data_type_code          reference_name
# 11               2.0              NIHON-KOKI
# 14               2.0              NIHON-KOKI
# 30               2.0              NIHON-KOKI
# 50               2.0  MONTOKUTENNO-JITSUROKU
# 52               2.0  MONTOKUTENNO-JITSUROKU
# ...              ...                     ...
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)
#
# [825 rows x 6 columns]

# %% [markdown]
# ## 12. How many times was our data from a title in Japanese poetry?
#
# You'll need to read the documentation inside of the Excel file.

# %%
df.data_type_code.value_counts()
jp_pt = df[df.data_type_code == 4]
len(jp_pt)
# Out:
# 39

# %%
#The number of times is 39

# %% [markdown]
# ## 13. Show only the years where our data was from a title in Japanese poetry

# %%
jp_pt.ad
# Out:
# 90       891
# 94       895
# 95       896
# 122      923
# 154      955
# 168      969
# 206     1007
# 232     1033
# 235     1036
# 259     1060
# 260     1061
# 283     1084
# 294     1095
# 381     1182
# 389     1190
# 400     1201
# 415     1216
# 418     1219
# 420     1221
# 422     1223
# 435     1236
# 464     1265
# 467     1268
# 468     1269
# 470     1271
# 488     1289
# 500     1301
# 523     1324
# 529     1330
# 646     1447
# 652     1453
# 653     1454
# 673     1474
# 733     1534
# 791     1592
# 839     1640
# 860     1661
# 1045    1846
# 1062    1863
# Name: ad, dtype: int64

# %% [markdown]
# ## 14. Graph the full-flowering date (DOY) over time

# %%
df['full_flowering_date_doy'].plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## 15. Smooth out the graph
#
# It's so jagged! You can use `df.rolling` to calculate a rolling average.
#
# The following code calculates a **10-year mean**, using the `AD` column as the anchor. If there aren't 20 samples to work with in a row, it'll accept down to 5. Neat, right?
#
# ```python
# df.rolling(10, on='AD', min_periods=5)['Full-flowering date (DOY)'].mean().tail()
# ```
#
# In this case we're only looking at the final 5. You'll probably want to look at more!

# %%
df.rolling(20, on='ad', min_periods=5)['full_flowering_date_doy'].mean().tail().plot(ylim=(80, 120), kind = 'hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df.rolling(20, on='ad', min_periods=20)['full_flowering_date_doy'].mean().tail().plot(ylim=(80, 120), kind = 'hist')

# %% [markdown]
# Use the code above to create a new column called `rolling_date` in our dataset. It should be the 20-year rolling average of the flowering date. Then plot it, with the year on the x axis and the day of the year on the y axis.
#
# Try adding `ylim=(80, 120)` to your `.plot` command to make things look a little less dire.

# %% [markdown]
# ### 16. Add a month column
#
# Right now the "Full-flowering date" column is pretty rough. It uses numbers like '402' to mean "April 2nd" and "416" to mean "April 16th." Let's make a column to explain what month it happened in.
#
# * Every row that happened in April should have 'April' in the `month` column.
# * Every row that happened in March should have 'March' as the `month` column.
# * Every row that happened in May should have 'May' as the `month` column.
#
# There are **at least two ways to do this.**
#
# #### WAY ONE: The bad-yet-simple way
#
# If you don't want to use `pd.to_datetime`, you can use this as an sample for updating March. It finds everything with a date less than 400 and assigns `March` to the `month` column:
#
# ```python
# df.loc[df['Full-flowering date'] < 400, 'month'] = 'March'
# ```
#
# #### WAY TWO: The good-yet-complicated way
#
# * When you use `pd.to_datetime` pandas tries to figure out the date format automatically. If that doesn't work, you can also pass a `format=` argument that explains what the format is of the datetime. You use [the codes here](https://strftime.org/) to mark out where the days, months, etc are. For example, `2020-04-09` would be converted using `pd.to_datetime(df.colname, "format='%Y-%m-%d")`.
# * `errors='coerce'` will return `NaN` for missing values.
# * And remember how we used `df.date_column.dt.month` to get the number of the month? For the name, you use `dt.strftime` (string-formatted-time), and pass it [the same codes](https://strftime.org/) to tell it what to do. For example, `df.date_column.dt.strftime("%Y-%m-%d")` would give you `"2020-04-09"`.

# %%
df.loc[df['full_flowering_date'] < 400, 'march'] = 'march'
df
# Out:
#         ad  full_flowering_date_doy  full_flowering_date  source_code  \
# 0      801                      NaN                  NaN          NaN
# 1      802                      NaN                  NaN          NaN
# 2      803                      NaN                  NaN          NaN
# 3      804                      NaN                  NaN          NaN
# 4      805                      NaN                  NaN          NaN
# ...    ...                      ...                  ...          ...
# 1210  2011                     99.0                409.0          8.0
# 1211  2012                    101.0                410.0          8.0
# 1212  2013                     93.0                403.0          8.0
# 1213  2014                     94.0                404.0          8.0
# 1214  2015                     93.0                403.0          8.0
#
#       data_type_code          reference_name march
# 0                NaN                     NaN   NaN
# 1                NaN                     NaN   NaN
# 2                NaN                     NaN   NaN
# 3                NaN                     NaN   NaN
# 4                NaN                     NaN   NaN
# ...              ...                     ...   ...
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)   NaN
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)   NaN
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)   NaN
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)   NaN
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)   NaN
#
# [1215 rows x 7 columns]

# %%
df.loc[df['full_flowering_date'] > 400, 'april'] = 'april'
df
# Out:
#         ad  full_flowering_date_doy  full_flowering_date  source_code  \
# 0      801                      NaN                  NaN          NaN
# 1      802                      NaN                  NaN          NaN
# 2      803                      NaN                  NaN          NaN
# 3      804                      NaN                  NaN          NaN
# 4      805                      NaN                  NaN          NaN
# ...    ...                      ...                  ...          ...
# 1210  2011                     99.0                409.0          8.0
# 1211  2012                    101.0                410.0          8.0
# 1212  2013                     93.0                403.0          8.0
# 1213  2014                     94.0                404.0          8.0
# 1214  2015                     93.0                403.0          8.0
#
#       data_type_code          reference_name march  april
# 0                NaN                     NaN   NaN    NaN
# 1                NaN                     NaN   NaN    NaN
# 2                NaN                     NaN   NaN    NaN
# 3                NaN                     NaN   NaN    NaN
# 4                NaN                     NaN   NaN    NaN
# ...              ...                     ...   ...    ...
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)   NaN  april
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)   NaN  april
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)   NaN  april
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)   NaN  april
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)   NaN  april
#
# [1215 rows x 8 columns]

# %%
df.loc[df['full_flowering_date'] >= 400, 'may'] = 'may'
df
# Out:
#         ad  full_flowering_date_doy  full_flowering_date  source_code  \
# 0      801                      NaN                  NaN          NaN
# 1      802                      NaN                  NaN          NaN
# 2      803                      NaN                  NaN          NaN
# 3      804                      NaN                  NaN          NaN
# 4      805                      NaN                  NaN          NaN
# ...    ...                      ...                  ...          ...
# 1210  2011                     99.0                409.0          8.0
# 1211  2012                    101.0                410.0          8.0
# 1212  2013                     93.0                403.0          8.0
# 1213  2014                     94.0                404.0          8.0
# 1214  2015                     93.0                403.0          8.0
#
#       data_type_code          reference_name march  april  may
# 0                NaN                     NaN   NaN    NaN  NaN
# 1                NaN                     NaN   NaN    NaN  NaN
# 2                NaN                     NaN   NaN    NaN  NaN
# 3                NaN                     NaN   NaN    NaN  NaN
# 4                NaN                     NaN   NaN    NaN  NaN
# ...              ...                     ...   ...    ...  ...
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)   NaN  april  may
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)   NaN  april  may
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)   NaN  april  may
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)   NaN  april  may
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)   NaN  april  may
#
# [1215 rows x 9 columns]

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [ad, full_flowering_date_doy, full_flowering_date, source_code, data_type_code, reference_name, march, april, may]
# Index: []

# %% [markdown]
# ### 17. Using your new column, how many blossomings happened in each month?

# %%
df.march.value_counts()
# Out:
# march    10
# Name: march, dtype: int64

# %%
df.april.value_counts()
# Out:
# april    817
# Name: april, dtype: int64

# %%
df.may.value_counts()
# Out:
# may    817
# Name: may, dtype: int64

# %% [markdown]
# ### 18. Graph how many blossomings happened in each month.

# %%
df.loc[df[]].plot()

#.groupby.april.value_counts().hist(bins=5)
#df['full_flowering_date_doy'].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('march', 'april', 'may')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [44], line 1
# ----> 1 df.loc[df['march','april','may']].plot()
#       3 #.groupby.april.value_counts().hist(bins=5)
#       4 #df['full_flowering_date_doy'].plot()
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/pandas/core/frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: ('march', 'april', 'may')

# %% [markdown]
# ###### 19. Adding a day-of-month column
#
# Now we're going to add a new column called `day_of_month.` Depending on what you did above, it might be a little tougher since the `Full-flowering date` column is a *float* instead of an integer.
#
# *Tip: If your method involves `.astype(int)` it isn't going to work since it's missing data, you can add `.dropna().astype(int)` instead.*

# %%
.dropna().astype(int)

# %% [markdown]
# ### 20. Adding a date column
#
# If you don't have one yet, take the `'month'` and `'day_of_month'` columns and combine them in order to create a new string-like column called `'date'`. You could alternatively use `.dt.strftime` as mentioned above, or *just totally skip this one if you have an actual datetime column*.

# %% [markdown]
# # YOU ARE DONE.
#
# And **incredible.**
